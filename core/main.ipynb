# %%
# %pip install plotly
# Out:
# ...
#   Using cached plotly-5.18.0-py3-none-any.whl.metadata (7.0 kB)
# ...
# Using cached plotly-5.18.0-py3-none-any.whl (15.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -r C:/Projects/AgriTechiesHackzion/requirements.txt
# Out:
# ...
#   Using cached comm-0.2.0-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached debugpy-1.8.0-cp311-cp311-win_amd64.whl.metadata (1.1 kB)
# ...
#      ---------------------------------------- 0.0/159.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/159.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/159.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/159.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/159.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/159.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/159.4 kB ? eta -:--:--
#      ------- ------------------------------ 30.7/159.4 kB 65.4 kB/s eta 0:00:02
#      -------------- ---------------------- 61.4/159.4 kB 130.9 kB/s eta 0:00:01
#      -------------- ---------------------- 61.4/159.4 kB 130.9 kB/s eta 0:00:01
#      -------------- ---------------------- 61.4/159.4 kB 130.9 kB/s eta 0:00:01
# ...

# %%
# %pip install ultralytics
